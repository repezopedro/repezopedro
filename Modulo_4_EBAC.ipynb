# %% [markdown]
# <a href="https://colab.research.google.com/github/repezopedro/repezopedro/blob/main/Modulo_4_EBAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Aula 1

# %%
# %%writefile banco.csv
# age,job,marital,education,default,balance,housing,loan
# 30,unemployed,married,primary,no,1787,no,no
# 33,services,married,secondary,no,4789,yes,yes
# 35,management,single,tertiary,no,1350,yes,no
# 30,management,married,tertiary,no,1476,yes,yes
# 59,blue-collar,married,secondary,no,0,yes,no
# 35,management,single,tertiary,no,747,no,no
# 36,self-employed,married,tertiary,no,307,yes,no
# 39,technician,married,secondary,no,147,yes,no
# 41,entrepreneur,married,tertiary,no,221,yes,no
# 43,services,married,primary,no,-88,yes,yes
# Out:
# Writing banco.csv

# %%
conteudo = None

with open(file = './banco.csv', mode= 'r', encoding='utf8') as arquivo:
  conteudo = arquivo.read()

print(conteudo)

print('\n')

#para arquivos muito pesados nao se recomenda o metodo 'read.
#Usando o 'read.readline o python vai ler uma linha de cada vez, deixando o arquivo mais agil.

conteudo = [] #outra forma de ler um conjunto vazio
with open(file = './banco.csv' , mode ='r', encoding = 'utf8') as arquivo:
  linha = arquivo.readline()
  while linha:
    conteudo.append(linha)
    linha = arquivo.readline() # vai ler linha a linha
print(conteudo) #imprimiu em formato de conjunto
#
# Out:
# age,job,marital,education,default,balance,housing,loan
# 30,unemployed,married,primary,no,1787,no,no
# 33,services,married,secondary,no,4789,yes,yes
# 35,management,single,tertiary,no,1350,yes,no
# 30,management,married,tertiary,no,1476,yes,yes
# 59,blue-collar,married,secondary,no,0,yes,no
# 35,management,single,tertiary,no,747,no,no
# 36,self-employed,married,tertiary,no,307,yes,no
# 39,technician,married,secondary,no,147,yes,no
# 41,entrepreneur,married,tertiary,no,221,yes,no
# 43,services,married,primary,no,-88,yes,yes
#
#
#
# ...

# %%
#para organizar melhor vou imprimir em um laço 'for' (imprimindo como conjuntos distintos cada linha)

for linha in conteudo:
  print(conteudo)
# Out:
# ['age,job,marital,education,default,balance,housing,loan\n', '30,unemployed,married,primary,no,1787,no,no\n', '33,services,married,secondary,no,4789,yes,yes\n', '35,management,single,tertiary,no,1350,yes,no\n', '30,management,married,tertiary,no,1476,yes,yes\n', '59,blue-collar,married,secondary,no,0,yes,no\n', '35,management,single,tertiary,no,747,no,no\n', '36,self-employed,married,tertiary,no,307,yes,no\n', '39,technician,married,secondary,no,147,yes,no\n', '41,entrepreneur,married,tertiary,no,221,yes,no\n', '43,services,married,primary,no,-88,yes,yes\n']
# ...

# %%
for linha in conteudo: #imprimindo cada linha individualmente
  print(linha)
# Out:
# age,job,marital,education,default,balance,housing,loan
#
# 30,unemployed,married,primary,no,1787,no,no
#
# 33,services,married,secondary,no,4789,yes,yes
#
# 35,management,single,tertiary,no,1350,yes,no
#
# 30,management,married,tertiary,no,1476,yes,yes
#
# 59,blue-collar,married,secondary,no,0,yes,no
#
# 35,management,single,tertiary,no,747,no,no
#
# 36,self-employed,married,tertiary,no,307,yes,no
#
# 39,technician,married,secondary,no,147,yes,no
#
# 41,entrepreneur,married,tertiary,no,221,yes,no
#
# 43,services,married,primary,no,-88,yes,yes

# %%
arquivo_idades = []
with open(file = './banco.csv', mode= 'r', encoding = 'utf8') as arquivo:
  linha = arquivo.readline() #Extrair apenas a primeira linha
print(linha)


print('\n')

#Trabalhando para extrair apenas a primeira coluna
idades = []
with open(file = './banco.csv', mode= 'r', encoding = 'utf8') as arquivo:
  linha = arquivo.readline() #lê a primeira linha
  linha = arquivo.readline() #lê a linha seguinte
  while linha:
    separar_linha = linha.split(sep=',') #quebra a string nas vírgulas e salva o resultado em uma lista
    idade = separar_linha[0] #seleciona o primeiro elemento da lista criada acima
    idade = int(idade) #converte o valor para int
    idades.append(idade) #adiciona o valor na lista idades
    linha = arquivo.readline() #lê uma nova linha

print(idades)
# Out:
# age,job,marital,education,default,balance,housing,loan
#
#
#
# [30, 33, 35, 30, 59, 35, 36, 39, 41, 43]

# %% [markdown]
# ##Aula 2

# %% [markdown]
# Modos de abertura de arquivos com o método 'open':
#
# **r** = read (modo de leitura). Mais seguro!
#
# **w** = write (modo de escrita). Sobrescreve arquivo. Caso o arquivo não exista ele será criado
#
# **a** = Abrir arquivo para acrescentar informação (não sobrescrever)

# %% [markdown]
# *   Modo de escrita **w**

# %%
#Usando o comando "idades" extraído do arquivo 'banco.csv'
with open(file = 'idades.csv', mode = 'w', encoding = 'utf=8') as fp:
  linha = 'idade' + '\n'
  fp.write(linha)
  for idade in idades:
    linha = str(idade) + '\n'
    fp.write(linha)

# %% [markdown]
# *   Modo de escrita **a**

# %%
with open(file = 'idades.csv', mode = 'a', encoding = 'utf8') as fp:
  for idade in idades:
    linha = str(idade + 100) + '\n'
    fp.write(linha)

# %%
#reescrevendo o arquivo em outra extensão:

# %%writefile banco-texto.txt
age,job,marital,education,default,balance,housing,loan
30,unemployed,married,primary,no,1787,no,no
33,services,married,secondary,no,4789,yes,yes
35,management,single,tertiary,no,1350,yes,no
30,management,married,tertiary,no,1476,yes,yes
59,blue-collar,married,secondary,no,0,yes,no
35,management,single,tertiary,no,747,no,no
36,self-employed,married,tertiary,no,307,yes,no
39,technician,married,secondary,no,147,yes,no
41,entrepreneur,married,tertiary,no,221,yes,no
43,services,married,primary,no,-88,yes,yes
# Out:
# Overwriting banco-texto.txt

# %%
 with open(file = './banco-texto.txt', mode = 'r', encoding = 'utf8') as leitura:
  with open(file = './banco.csv.csv', mode = 'w', encoding = 'utf8') as escrita:
    linha = leitura.readline()
    while linha:
      escrita.write(linha)
      linha = leitura.readline()

# %% [markdown]
# ##Aula 3

# %% [markdown]
# > Motivação da aula: Calculando retorno de investimento sobre alguns cenários

# %%
#Esudando como importar informação de determinado site (neste caso, taxa de juros)

#Importando bibliotecas
# !pip install mplcyberpunk
# !pip install matplotlib
# !pip install python-bcb
# !pip install datetime
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 65.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
import mplcyberpunk
from bcb import sgs #modo para conversão de moedas
from bcb import currency

#personalizações de gráficos (analisar biblioteca!)
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
from matplotlib.dates import date2num

#para interação temportal e organização cronológica
from datetime import datetime
from datetime import timedelta

# %%
plt.style.use ("cyberpunk")

# %%
#série Selic
selic = sgs.get({'selic': '432'}, start = '2003-01-01')

selic
# Out:
#             selic
# Date
# 2003-01-01  25.00
# 2003-01-02  25.00
# 2003-01-03  25.00
# 2003-01-04  25.00
# 2003-01-05  25.00
# ...           ...
# 2023-12-18  11.75
# 2023-12-19  11.75
# 2023-12-20  11.75
# 2023-12-21  11.75
# 2023-12-22  11.75
#
# [7661 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['selic'].plot(kind='hist', bins=20, title='selic')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
# ...

# %%
#Plotando um gráfico da variação da SELIC

fig, ax = plt.subplots()

plt.style.use('cyberpunk')

ax.plot(selic.index, selic['selic'])
ax.yaxis.set_major_formatter(mtick.PercentFormatter()) #formatar a taxa em %
ax.grid(False) #retirar o grid do gráfico
#plt.savefig('selic.png', dpi = 300) #salvar o gráfico como imagem

plt.show()

# %%
import pandas_datareader as pdr
from datetime import datetime

# Obtendo a série Selic
selic_series = pdr.get_data_fred('GS1')

# Extraindo a taxa mais recente
taxa_selic_atual = selic_series.tail(1)['GS1'].iloc[0]

print(f"A taxa Selic atual é: {taxa_selic_atual}")
# Out:
# A taxa Selic atual é: 5.28

# %% [markdown]
# > Motivação

# %%
#Motivação: Caulular o juros composto de uma ação da Bolsa.

valor_inicial, taxa, anos = 1000, taxa_selic_atual , 10

#calculo básico de juros compostos
valor_final = valor_inicial
for ano in range(1, anos+1):
  valor_final = valor_final * (1 + (taxa_selic_atual/100))
valor_final = round(valor_final, 2)

#imprimindo resultado
print(f'Para a taxa básica de juros atual igual a {taxa_selic_atual}% e um valor aplicado inicial de R${valor_inicial} em {anos} anos, o retorno será de {valor_final}')

#formatando os valores para moeda
valor_final_formatado = "{:,.2f}".format(valor_final)
valor_inicial_formatado = "{:,.2f}".format(valor_inicial)

#imprimindo resultado
print(f'Para a taxa básica de juros atual igual a {taxa_selic_atual}% e um valor aplicado inicial de R${valor_inicial_formatado} em {anos} anos, o retorno será de R${valor_final_formatado}')
# Out:
# Para a taxa básica de juros atual igual a 5.28% e um valor aplicado inicial de R$1000 em 10 anos, o retorno será de 1672.86
# Para a taxa básica de juros atual igual a 5.28% e um valor aplicado inicial de R$1,000.00 em 10 anos, o retorno será de R$1,672.86

# %% [markdown]
# > Como seria para reaproveitar o código e evitar repetições:

# %%
def juros_compostos_anual(valor_inicial: float, taxa: float, anos: int) -> float:
  valor_final = valor_inicial
for ano in range(1, anos+1):
  valor_final = valor_final * (1 + (taxa_selic_atual/100))
valor_final = round(valor_final, 2)
print(f'Para a taxa básica de juros atual igual a {taxa_selic_atual}% e um valor aplicado inicial de R${valor_inicial} em {anos} anos, o retorno será de {valor_final}')

valor_inicial, taxa, anos = 1000, taxa_selic_atual , 10
# Out:
# Para a taxa básica de juros atual igual a 5.28% e um valor aplicado inicial de R$1000 em 10 anos, o retorno será de 2798.46

# %% [markdown]
# >> Conteúdo da aula

# %% [markdown]
# *  Modo **def**

# %% [markdown]
# def = 'nome'(param1, param2...):
#
# 'bloco de código'
#
# return'valor a ser retornado'
#
# variavel = 'nome da função'(param1, param2...)

# %%
#método 'def' serve para guardar um valor

def imprime(mensagem: str):
  print(mensagem)

texto = 'Vasco da Gama!!!'
imprime(mensagem = texto)
# Out:
# Vasco da Gama!!!

# %%
#Definição
def maiusculo(texto: str) -> str:
  text_maiusculo = texto.upper()
  return text_maiusculo

nome = 'Pedro Muniz Repezo'
print(nome)

nome_maiusculo = maiusculo(texto=nome)
print(nome_maiusculo)
# Out:
# Pedro Muniz Repezo
# PEDRO MUNIZ REPEZO

# %%
#podemos retornar uma quantidade arbitraria de valores:

def extrair_usuario_email_provedor(email) -> (str, str):
  email_separado = email.split(sep='@') #quebrando a string em uma lista com o método 'split'
  usuario = email_separado[0] #atribuindo o primeiro valor [0] da lista ao usuario
  provedor = email_separado[1] #atrinbuindo o segundo valor [1] da lista ao provedor
  return usuario, provedor

# %%
email = 'repezo.pedro@gmail.com'

usuario, provedor = extrair_usuario_email_provedor(email=email)
print(usuario)
print(provedor)
# Out:
# repezo.pedro
# gmail.com

# %%
#Definindo Parametro

# %%
def pi() -> float:
  return pi()

# %%
print(pi)
# Out:
# <function pi at 0x7c8e7bdfbeb0>

# %%
def imprime_pi() -> None:
  print(3.14159265359)
  return None #return Nome é reduntante. É bom escrever para evidenciar que a função não retorna nada

# %%
imprime_pi()
# Out:
# 3.14159265359

# %%
def escreve_arquivo_csv(nome:str, cabecalho:str, conteudos:list) ->bool:

    try:
        with open(file=nome, mode= 'w', encoding='utf8') as pd:
          linha = cabecalho + '\n'
          pd.write(linha)
          for conteudo in conteudos:
            linha = str(conteudo) + '\n'
            pd.write(linha)

    except Exception as exc:
      print(exc)
      return False

    return True

# %%
nome = 'idades-funcao.csv'
cabecalho = 'idade'
conteudos = [30, 23, 55, 35, 45, 28, 26, 22, 31, 40]

escreveu_com_sucesso = escreve_arquivo_csv(nome=nome, cabecalho=cabecalho, conteudos=conteudos)
print(escreveu_com_sucesso)
# Out:
# True

# %% [markdown]
# ## REVISITANDO MOTIVAÇÃO - AULA 3

# %%
#Gostaria de revisitando a motivação da aula e acrescentar as seguintes possibilidades:

#definir uma caixa para digitar/testar taxa de juros.
#viabilizar um 'atingir meta'
#salvar resultados em uma tabela

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Digitar Variáveis

# %%
#Input de dados
valor_inicial_novo = float(input('Digite o valor aplicado:  R$'))
taxa_selic_aplicada = float(input('Digite a taxa de juros aplicada (%):  '))
anos = int(input('Digite o número de anos:  '))
# Out:
# Digite o valor aplicado:  R$1000
# Digite a taxa de juros aplicada (%):  5.28
# Digite o número de anos:  10

# %%
def juros_compostos_anual(valor_inicial_novo: float, taxa_selic_aplicada: float, anos: int, valor_final: float) -> float:
  valor_final = valor_inicial_novo
for ano in range(1, anos+1):
  valor_final = valor_final * (1 + (taxa_selic_atual/100))
valor_final = round(valor_final, 2)

#imprimindo resultado
print(f'Para a taxa básica de juros atual igual a {taxa_selic_atual}% e um valor aplicado inicial de R${valor_inicial} em {anos} anos, o retorno será de R${valor_final}')

print('\n')
# Out:
# Para a taxa básica de juros atual igual a 5.28% e um valor aplicado inicial de R$1000 em 10 anos, o retorno será de R$7831.35

# %% [markdown]
# ###Atingir Meta

# %%
#viabilizar um 'atingir meta'

valor_final_desejado = float(input('Digite o valor final desejado:  R$'))
anos_meta = int(input('Digite o número de anos:  '))
# Out:
# Digite o valor final desejado:  R$5000
# Digite o número de anos:  4

# %%
valor_inicial_necessario = valor_final_desejado / (1 + (taxa_selic_atual/100))**anos_meta
valor_inicial_necessario = round(valor_inicial_necessario, 2)

#formatando os valores para moeda
valor_final_format = "{:,.2f}".format(valor_final_desejado)
valor_inicial_format = "{:,.2f}".format(valor_inicial_necessario)

#imprimindo com valor formatado
print(f'Para atingir o valor final de R${valor_final_format} em {anos_meta} anos, o valor inicial necessário é de R${valor_inicial_format}')
# Out:
# Para atingir o valor final de R$5,000.00 em 4 anos, o valor inicial necessário é de R$4,069.93

# %% [markdown]
# ###Salvar resultados

# %%
#salvando os resultados

#criando um dataframe
df = pd.DataFrame()

#adicionando as colunas
df['Valor Inicial'] = valor_inicial_novo
df['Taxa de Juros'] = taxa_selic_aplicada
df['Anos'] = anos
df['Valor Final'] = valor_final

#salvando o dataframe em um arquivo CSV
df.to_csv('resultados.csv', index=False)

# %%
with open(file = 'resultados.csv', mode = 'a', encoding = 'utf8') as fp:
  linha = 'hipótese' + '\n'
  fp.write(linha)
  for n in str(valor_inicial_novo):
    linha = str(n) + '\n'
    fp.write(linha)
